# %%
import os
import json

# %%
data_path = "/data/datasets/jsons/train.json"

# %%
with open(data_path, "r") as f:
    json_dic = json.load(f)

# %%
json_dic.keys()
# Out:
# dict_keys(['images'])

# %%
json_dic['images'].keys()
# Out:
# dict_keys(['drp.en_ko.in_house.selectstar_000003.jpg', 'drp.en_ko.in_house.selectstar_000005.jpg', 'drp.en_ko.in_house.selectstar_000006.jpg', 'drp.en_ko.in_house.selectstar_000008.jpg', 'drp.en_ko.in_house.selectstar_000009.jpg', 'drp.en_ko.in_house.selectstar_000010.jpg', 'drp.en_ko.in_house.selectstar_000011.jpg', 'drp.en_ko.in_house.selectstar_000012.jpg', 'drp.en_ko.in_house.selectstar_000014.jpg', 'drp.en_ko.in_house.selectstar_000015.jpg', 'drp.en_ko.in_house.selectstar_000016.jpg', 'drp.en_ko.in_house.selectstar_000019.jpg', 'drp.en_ko.in_house.selectstar_000020.jpg', 'drp.en_ko.in_house.selectstar_000021.jpg', 'drp.en_ko.in_house.selectstar_000022.jpg', 'drp.en_ko.in_house.selectstar_000023.jpg', 'drp.en_ko.in_house.selectstar_000024.jpg', 'drp.en_ko.in_house.selectstar_000026.jpg', 'drp.en_ko.in_house.selectstar_000027.jpg', 'drp.en_ko.in_house.selectstar_000028.jpg', 'drp.en_ko.in_house.selectstar_000033.jpg', 'drp.en_ko.in_house.selectstar_000034.jpg', 'drp.en_ko.in_house
# ...

# %%
json_dic['images']['drp.en_ko.in_house.selectstar_000003.jpg'].keys()
# Out:
# dict_keys(['words', 'img_w', 'img_h'])

# %%
json_dic['images']['drp.en_ko.in_house.selectstar_000003.jpg']
# Out:
# {'words': {'0001': {'points': [[235.83, 91.13],
#     [430.55, 108.13],
#     [433.64, 133.37],
#     [235.83, 119.46]],
#    'orientation': 'Horizontal',
#    'language': ['ko']},
#   '0002': {'points': [[457.34, 113.79],
#     [468.67, 113.79],
#     [468.67, 130.79],
#     [457.34, 130.79]],
#    'orientation': 'Horizontal',
#    'language': None},
#   '0003': {'points': [[493.91, 114.83],
#     [550.43, 119.49],
#     [551.09, 143.67],
#     [493.24, 140.34]],
#    'orientation': 'Horizontal',
#    'language': None},
#   '0004': {'points': [[232.74, 118.95],
#     [345.55, 125.13],
#     [346.58, 149.85],
#     [233.25, 144.7]],
#    'orientation': 'Horizontal',
#    'language': ['ko']},
#   '0005': {'points': [[233.79, 145.49],
#     [370.86, 155.73],
#     [371.15, 178.76],
#     [234.36, 171.65]],
#    'orientation': 'Horizontal',
#    'language': None},
#   '0006': {'points': [[379.68, 156.86],
#     [419.21, 160.2],
#     [419.21, 181.32],
#     [379.68, 181.32]],
# ...
