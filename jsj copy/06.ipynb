# %%
import os
import json

# %%
os.listdir("../hiertext/gt")
# Out:
# ['train.jsonl', 'validation.jsonl']

# %%
with open("../hiertext/gt/train.jsonl", "r") as f:
    train_json = json.load(f)

# %%
with open("/data/datasets/jsons/train_ver02.json", "r") as f:
    origin_json = json.load(f)

# %%
train_json.keys()
# Out:
# dict_keys(['info', 'annotations'])

# %%
train_json['info']
# Out:
# {'date': '2022-03-16', 'version': 'v1.0'}

# %%
type(train_json['annotations'])
# Out:
# list

# %%
train_json['annotations'][0].keys()
# Out:
# dict_keys(['image_id', 'paragraphs', 'image_width', 'image_height'])

# %%
train_json['annotations'][0]
# Out:
# {'image_id': '0006289e4f292bcd',
#  'paragraphs': [{'vertices': [[270, 185],
#     [690, 326],
#     [743, 293],
#     [685, 137],
#     [597, 42],
#     [293, 43]],
#    'legible': True,
#    'lines': [{'vertices': [[330, 56], [741, 208], [697, 327], [285, 175]],
#      'text': 'MOZART',
#      'legible': True,
#      'handwritten': False,
#      'vertical': False,
#      'words': [{'vertices': [[330, 56], [741, 208], [697, 327], [285, 175]],
#        'text': 'MOZART',
#        'legible': True,
#        'handwritten': False,
#        'vertical': False}]},
#     {'vertices': [[467, 40], [671, 113], [650, 172], [445, 99]],
#      'text': 'MIKE',
#      'legible': True,
#      'handwritten': False,
#      'vertical': False,
#      'words': [{'vertices': [[467, 40], [671, 113], [650, 172], [445, 99]],
#        'text': 'MIKE',
#        'legible': True,
#        'handwritten': False,
#        'vertical': False}]}]},
#   {'vertices': [[791, 238], [899, 238], [897, 212], [795, 213]],
# ...

# %%
train_json['annotations'][0]['paragraphs'][0].keys()
# Out:
# dict_keys(['vertices', 'legible', 'lines'])

# %%
train_json['annotations'][0]['paragraphs'][0]['vertices']
# Out:
# [[270, 185], [690, 326], [743, 293], [685, 137], [597, 42], [293, 43]]

# %%
train_json['annotations'][0]['paragraphs'][0]['legible']
# Out:
# True

# %%
train_json['annotations'][0]['paragraphs'][0]['lines']
# Out:
# [{'vertices': [[330, 56], [741, 208], [697, 327], [285, 175]],
#   'text': 'MOZART',
#   'legible': True,
#   'handwritten': False,
#   'vertical': False,
#   'words': [{'vertices': [[330, 56], [741, 208], [697, 327], [285, 175]],
#     'text': 'MOZART',
#     'legible': True,
#     'handwritten': False,
#     'vertical': False}]},
#  {'vertices': [[467, 40], [671, 113], [650, 172], [445, 99]],
#   'text': 'MIKE',
#   'legible': True,
#   'handwritten': False,
#   'vertical': False,
#   'words': [{'vertices': [[467, 40], [671, 113], [650, 172], [445, 99]],
#     'text': 'MIKE',
#     'legible': True,
#     'handwritten': False,
#     'vertical': False}]}]

# %%
train_json['annotations'][0]['paragraphs'][0]['lines'][0].keys()
# Out:
# dict_keys(['vertices', 'text', 'legible', 'handwritten', 'vertical', 'words'])

# %%
origin_json['images']['5350093-2001-0001-0001.jpg']
# Out:
# {'words': {'0001': {'points': [[65, 93], [187, 93], [187, 221], [65, 221]],
#    'orientation': 'Horizontal',
#    'language': ['ko']},
#   '0003': {'points': [[889, 323], [1066, 323], [1066, 383], [889, 383]],
#    'orientation': 'Horizontal',
#    'language': ['ko']},
#   '0004': {'points': [[1079, 323], [1281, 323], [1281, 383], [1079, 383]],
#    'orientation': 'Horizontal',
#    'language': ['ko']},
#   '0005': {'points': [[1294, 323], [1449, 323], [1449, 383], [1294, 383]],
#    'orientation': 'Horizontal',
#    'language': ['ko']},
#   '0006': {'points': [[1465, 320], [1683, 320], [1683, 383], [1465, 383]],
#    'orientation': 'Horizontal',
#    'language': ['ko']},
#   '0007': {'points': [[886, 383], [971, 383], [971, 475], [886, 475]],
#    'orientation': 'Horizontal',
#    'language': ['ko']},
#   '0008': {'points': [[1265, 383], [1344, 383], [1344, 471], [1265, 471]],
#    'orientation': 'Horizontal',
#    'language': ['ko']},
# ...
