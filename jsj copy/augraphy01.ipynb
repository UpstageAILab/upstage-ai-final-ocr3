# %%
import cv2
import numpy as np
from augraphy import *
import matplotlib.pyplot as plt

# %%
image = cv2.imread("/data/datasets/images/train/5350093-2001-0001-0001.jpg")

# %%
lighting_gradient_gaussian = LightingGradient(light_position=None,
                                              direction=None,
                                              max_brightness=255,
                                              min_brightness=0,
                                              mode="gaussian",
                                              transparency=0.3
                                              )

img_lighting_gradient_gaussian = lighting_gradient_gaussian(image)
#cv2.imshow("lighting_gradient_gaussian", img_lighting_gradient_gaussian)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 lighting_gradient_gaussian = LightingGradient(light_position=None,
#       2                                               direction=None,
#       3                                               max_brightness=255,
#       4                                               min_brightness=0,
#       5                                               mode="gaussian",
#       6                                               transparency=0.3
#       7                                               )
#       9 img_lighting_gradient_gaussian = lighting_gradient_gaussian(image)
#      10 #cv2.imshow("lighting_gradient_gaussian", img_lighting_gradient_gaussian)
#
# NameError: name 'LightingGradient' is not defined

# %%
plt.imshow(img_lighting_gradient_gaussian)
